# %%
# Third Party Imports
import pandas as pd
import sklearn
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

import bat
from bat import log_to_dataframe
from bat import dataframe_to_matrix
print('DONE')
# Out:
# DONE

# %%
# Create a Pandas dataframe from a Bro log
bro_df = log_to_dataframe.LogToDataFrame('/home/dane/bro_logs/1k_dnsonly.log')

# Print out the head of the dataframe
bro_df.head()
print('DONE')
# Out:
# Successfully monitoring /home/dane/bro_logs/1k_dnsonly.log...
# DONE

# %%
# Using Pandas we can easily and efficiently compute additional data metrics
# Here we use the vectorized operations of Pandas/Numpy to compute query length
bro_df['query_length'] = bro_df['query'].str.len()
print('DONE')
bro_df.head()
#print(bro_df['id.resp_p'])
# Out:
# DONE
#                                AA     RA     RD     TC TTLs  Z answers  \
# ts
# 2018-12-07 21:00:00.098604  False  False  False  False    -  0       -
# 2018-12-07 21:00:01.239240  False  False  False  False    -  0       -
# 2018-12-07 21:00:01.821986  False  False  False  False    -  0       -
# 2018-12-07 21:00:00.122574  False  False  False  False    -  0       -
# 2018-12-07 21:00:00.130560  False  False  False  False    -  0       -
#
#                                   id.orig_h  id.orig_p       id.resp_h  \
# ts
# 2018-12-07 21:00:00.098604  192.168.230.115      45541  192.168.196.52
# 2018-12-07 21:00:01.239240  192.168.230.137      54504  192.168.196.52
# 2018-12-07 21:00:01.821986  192.168.230.135      44810  192.168.196.52
# 2018-12-07 21:00:00.122574  192.168.230.115      40547  192.168.196.52
# 2018-12-07 21:00:00.130560  192.168.230.115      59178  192.168.196.52
#
#                                 ...       qtype qtype_name  query rcode  \
# ts                              ...
# 2018-12-07 21:00:00.098604      ...           0          -      -     3
# 2018-12-07 21:00:01.239240      ...           0          -      -     3
# 2018-12-07 21:00:01.821986      ...           0          -      -     3
# 2018-12-07 21:00:00.122574      ...           0          -      -     3
# 2018-12-07 21:00:00.130560      ...           0          -      -     3
#
#                             rcode_name rejected    rtt  trans_id  \
# ts
# 2018-12-07 21:00:00.098604    NXDOMAIN    False 0 days     39509
# 2018-12-07 21:00:01.239240    NXDOMAIN    False 0 days     49641
# 2018-12-07 21:00:01.821986    NXDOMAIN    False 0 days     50003
# 2018-12-07 21:00:00.122574    NXDOMAIN    False 0 days     39098
# 2018-12-07 21:00:00.130560    NXDOMAIN    False 0 days     40814
#
#                                            uid  query_length
# ts
# 2018-12-07 21:00:00.098604  CIHzuU1CZBR1VwXJf8             1
# 2018-12-07 21:00:01.239240   CJUNRuZ0jbCbtiyRj             1
# 2018-12-07 21:00:01.821986  Co1wIi2KlwgLBnn2Gb             1
# 2018-12-07 21:00:00.122574   CokYLVSPhJrDtT3kk             1
# 2018-12-07 21:00:00.130560  C6SMF13vvOWwaWcTOh             1
#
# [5 rows x 24 columns]

# %% [markdown]
# ## DNS records are a mix of numeric and categorical data
# When we look at the dns records some of the data is numerical and some of it is categorical so we'll need a way of handling both data types in a generalized way. bat has a DataFrameToMatrix class that handles a lot of the details and mechanics of combining numerical and categorical data, we'll use below.

# %%
# These are the features we want (note some of these are categorical :)
features = ['query', 'qclass_name', 'qtype_name', 'rcode_name',]
feature_df = bro_df[features]
feature_df.head()
print('DONE')
# Out:
# DONE

# %% [markdown]
# <div style="float: right; margin: -10px 40px -10px 40px"><img src="images/transformers.png" width="200px"></div>
# ## Transformers
# **We'll now use a bat scikit-learn tranformer class to convert the Pandas DataFrame to a numpy ndarray (matrix). Yes it's awesome... I'm not sure it's Optimus Prime awesome.. but it's still pretty nice.**

# %%
# Use the bat DataframeToMatrix class (handles categorical data)
# You can see below it uses a heuristic to detect category data. When doing
# this for real we should explicitly convert before sending to the transformer.
to_matrix = dataframe_to_matrix.DataFrameToMatrix()
bro_matrix = to_matrix.fit_transform(feature_df)
print('DONE')
# Out:
# Changing column query to category...
# Changing column qclass_name to category...
# Changing column qtype_name to category...
# Changing column rcode_name to category...
# DONE

# %%
# Just showing that the class is tracking categoricals and normalization maps
print(to_matrix.cat_columns)
print(to_matrix.norm_map)
print('DONE')
# Out:
# ['query', 'qclass_name', 'qtype_name', 'rcode_name']
# {}
# DONE

# %%
# Now we're ready for scikit-learn!
# Just some simple stuff for this example, KMeans and TSNE projection
kmeans = KMeans(n_clusters=3).fit_predict(bro_matrix)
projection = TSNE().fit_transform(bro_matrix)
print('DONE')
# Out:
# DONE

# %%
# Now we can put our ML results back onto our dataframe!
bro_df['tsne_0'] = projection[:, 0] # Projection X Column
bro_df['tsne_1'] = projection[:, 1] # Projection Y Column
bro_df['cluster'] = kmeans
bro_df[['query', 'proto', 'tsne_0', 'tsne_1', 'cluster']].head()  # Showing the scikit-learn results in our dataframe
# Plotting defaults
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 12.0
plt.rcParams['figure.figsize'] = 15.0, 7.0
# Now use dataframe group by cluster
cluster_groups = bro_df.groupby('cluster')

# Plot the Machine Learning results
fig, ax = plt.subplots()
colors = {0:'green', 1:'blue', 2:'red'}#, 3:'orange', 4:'purple',}
for key, group in cluster_groups:
    group.plot(ax=ax, kind='scatter', x='tsne_0', y='tsne_1', alpha=0.15, s=50,
               label='Cluster: {:d}'.format(key), color=colors[key])
print('DONE')
# Out:
# DONE

# %%
# Now print out the details for each cluster
pd.set_option('display.width', 1000)
show_fields = ['query', 'Z', 'proto', 'qtype_name', 
               'cluster','AA', 'RA', 'RD',
               'TC', 'rejected','qclass_name',
               'rcode_name', 'query_length']
for key, group in cluster_groups:
    print('\nCluster {:d}: {:d} observations'.format(key, len(group)))
    print(group[show_fields].head())
print(len(bro_df))
# Cluster 0 = normal query
# Cluster 1 = successful dns query to the "internet" by an HP laserjet printer
# Cluster 2 = blank query without query type and length of 1
print('DONE')
# Out:
# Cluster 0: 335 observations
#                            query  Z proto qtype_name  cluster     AA     RA     RD     TC  rejected qclass_name rcode_name  query_length
# ts
# 2018-12-07 21:00:00.098604     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:01.239240     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:01.821986     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.122574     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.130560     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
#
# Cluster 1: 658 observations
#                            query  Z proto qtype_name  cluster     AA     RA     RD     TC  rejected qclass_name rcode_name  query_length
# ts
# 2018-12-07 21:02:35.658595     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 21:02:35.666563     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 21:02:35.658595     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 21:02:35.666563     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 21:02:35.666563     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
#
# Cluster 2: 8 observations
#                                                   query  Z proto qtype_name  cluster    AA    RA     RD     TC  rejected qclass_name rcode_name  query_length
# ts
# 2018-12-07 21:00:00.122574  51.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 21:00:00.154606  52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 19:00:00.194576  52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 19:00:00.194576  51.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 00:00:00.082592  52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 1001
# DONE

# %%
for key, group in cluster_groups:
    print('\nCluster {:d}: {:d} observations'.format(key, len(group)))
    print(group[show_fields])
print('DONE')
# Out:
# Cluster 0: 335 observations
#                            query  Z proto qtype_name  cluster     AA     RA     RD     TC  rejected qclass_name rcode_name  query_length
# ts
# 2018-12-07 21:00:00.098604     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:01.239240     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:01.821986     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.122574     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.130560     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.146601     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.154606     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.162575     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.162575     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:00.182573     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:01.962572     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:00:12.258610     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 21:01:00.174557     -  0   udp          -        0  False  False  False  False     False           -   NXDOMAIN             1
# 2018-12-07 09:53:17.295203     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:03.291200     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:55:25.287191     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:57:23.295231     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
# 2018-12-07 09:57:23.303220     -  0   udp          -        1  False  False  False  False      True           -   SERVFAIL             1
#
# [658 rows x 13 columns]
#
# Cluster 2: 8 observations
#                                                    query  Z proto qtype_name  cluster    AA    RA     RD     TC  rejected qclass_name rcode_name  query_length
# ts
# 2018-12-07 21:00:00.122574   51.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 21:00:00.154606   52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 19:00:00.194576   52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 19:00:00.194576   51.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 00:00:00.082592   52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 00:00:00.170593   50.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 09:00:00.266605   52.196.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            27
# 2018-12-07 09:00:00.278558  251.199.168.192.in-addr.arpa  0   udp          -        2  True  True  False  False     False           -    NOERROR            28
# DONE
